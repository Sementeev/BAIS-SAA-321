# %% [markdown]
# <a href="https://colab.research.google.com/github/Sementeev/BAIS-SAA-321/blob/main/Sementeev_Regression_Supercomputer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Выполнил: Сементеев А.А.,
# ## группа ПИ-321

# %% [markdown]
# Вычислительный эксперимент:

# %%
import time
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
reg = linear_model.LinearRegression()
np.random.seed(19130510) #Номер зачетки Сементеев А.А.
A = []
B = []
T = []
N = 10000
n = 1000

# %%
for i in range(n):
    t = time.time()
    x = np.random.uniform(low=150, high=200, size=N)
    e = np.random.normal(loc=0, scale=10, size=N)
    y = -100 + x + e
    reg.fit(x.reshape(-1, 1), y.reshape(-1, 1))
    A.append(reg.intercept_[0])
    B.append(reg.coef_[0][0])
    T.append(time.time() - t)

# %% [markdown]
# Анализ распределения:

# %%
plt.figure(figsize=(10, 6))
plt.hist(B, bins = 20, edgecolor='black', color='white')
plt.title('Histogram of B estimates')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(A, bins = 20, edgecolor='black', color='white')
plt.title('Histogram of A estimates')
plt.show()

# %% [markdown]
# Длительность расчётов:

# %%
min(T), np.median(T),max(T)
# Out:
# (0.001209259033203125, 0.0018894672393798828, 0.05353593826293945)

# %%
plt.figure(figsize=(10, 4))
plt.plot(T, marker='.')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.figure(figsize=(10, 4))
plt.plot(T[200:300], marker='.')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.figure(figsize=(10, 4))
plt.hist(T[200:300], bins = 30, edgecolor='black', color='white')
plt.show()
